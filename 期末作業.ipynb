# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivy6565/Ivy6565/blob/main/%E6%9C%9F%E6%9C%AB%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Ivy6565/fin_data/main/Balance_hw.csv"

# %%
df1= pd.read_csv(url,index_col=0,encoding='unicode_escape')

# %%
df1
# Out:
#                YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1203 Ve Wong   2023/12        4             Y     12      NTD
# 1234 HEY SONG  2023/12        4             Y     12      NTD
#
#                Total cash and cash equivalents  \
# CO_ID
# 1203 Ve Wong                         1612746.0
# 1234 HEY SONG                        1489381.0
#
#                Total current financial assets at fair value through profit or loss  \
# CO_ID
# 1203 Ve Wong                                                 0.0
# 1234 HEY SONG                                            60101.0
#
#                Financial assets at fair value through other comprehensive income - Current  \
# CO_ID
# 1203 Ve Wong                                                 0.0
# 1234 HEY SONG                                                0.0
#
#                Financial assets measured at amortized cost - Current  \
# CO_ID
# 1203 Ve Wong                                            355642.0
# ...

# %%
url = "https://raw.githubusercontent.com/Ivy6565/fin_data/main/Income_hw.csv"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#                YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 1203 Ve Wong   2023/12        4             Y     12      NTD
# 1234 HEY SONG  2023/12        4             Y     12      NTD
#
#                Gross operating revenue  Total rental revenue  \
# CO_ID
# 1203 Ve Wong                 6344049.0               59664.0
# 1234 HEY SONG               10972964.0                   0.0
#
#                Operating revenue - Disposal of lands  Interest revenue  \
# CO_ID
# 1203 Ve Wong                                     0.0               0.0
# 1234 HEY SONG                                    0.0               0.0
#
#                Operating revenue - disposal of investments  ...  \
# CO_ID                                                       ...
# 1203 Ve Wong                                           0.0  ...
# 1234 HEY SONG                                          0.0  ...
#
#                Preferred stock dividends  Diluted net income  \
# CO_ID
# ...

# %%
X1 ='Total current assets'
X2 ='Total current liabilities'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Earnings before interest and tax'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Total operating revenue'
VeWong ='1203 Ve Wong'
HEYSONG ='1234 HEY SONG'

# %%
A_VeWong = df1.loc['1203 Ve Wong',X1] - df1.loc['1203 Ve Wong', X2] / df1.loc['1203 Ve Wong', X3]

# %%
B_VeWong = df1.loc['1203 Ve Wong',X4]/df1.loc['1203 Ve Wong', X3]

# %%
C_VeWong = df2.loc['1203 Ve Wong',X5]/df1.loc['1203 Ve Wong', X3]

# %%
D_VeWong = df1.loc['1203 Ve Wong',X6]/df1.loc['1203 Ve Wong', X7]

# %%
E_VeWong = df2.loc['1203 Ve Wong',X8]/df1.loc['1203 Ve Wong', X3]

# %%
Z_score_VEWONG = 1.2*A_VeWong + 1.4*B_VeWong + 3.3*C_VeWong + 0.6*D_VeWong + 1.0*E_VeWong

# %%
Z_score_VEWONG,A_VeWong,B_VeWong,C_VeWong,D_VeWong,E_VeWong
# Out:
# (5406631.180886718,
#  4505523.816153234,
#  0.32123821511888295,
#  0.09317209409768792,
#  2.0184159775872974,
#  0.6332518395435636)

# %%
A_HEYSONG = df1.loc['1234 HEY SONG',X1] - df1.loc['1234 HEY SONG', X2] / df1.loc['1234 HEY SONG', X3]

# %%
B_HEYSONG = df1.loc['1234 HEY SONG',X4]/df1.loc['1234 HEY SONG', X3]

# %%
C_HEYSONG = df2.loc['1234 HEY SONG',X5]/df1.loc['1234 HEY SONG', X3]

# %%
D_HEYSONG = df1.loc['1234 HEY SONG',X6]/df1.loc['1234 HEY SONG', X7]

# %%
E_HEYSONG = df2.loc['1234 HEY SONG',X8]/df1.loc['1234 HEY SONG', X3]

# %%
Z_score_HEYSONG = 1.2*A_HEYSONG + 1.4*B_HEYSONG + 3.3*C_HEYSONG + 0.6*D_HEYSONG + 1.0*E_HEYSONG

# %%
Z_score_HEYSONG,A_HEYSONG,B_HEYSONG,C_HEYSONG,D_HEYSONG,E_HEYSONG
# Out:
# (9689820.55001421,
#  8074846.924020948,
#  0.6295134836792817,
#  0.053285991206413606,
#  4.53221763688716,
#  0.46469584332546265)
