# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivy6565/Ivy6565/blob/main/fred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='8a5af5da1c2e52872e5005ef243a9ff5')

# %%
data1 = fred.get_series('DJIA')

# %%
data1 = fred.get_series('DJIA', '6/1/2021')

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data2 = fred.get_series('RRPONTSYD')

# %%
data2 = fred.get_series('RRPONTSYD', '6/1/2021')

# %%
data1.plot()
data2.plot()
# Out:
# <Axes: >

# %%
df1 = data1.to_frame(name="DJIA")
df2 = data2.to_frame(name='RRPONTSYD')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(df_merged.index, df_merged['SP500'])
plt.plot(df_merged.index, df_merged['RRPONTSYD'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8d3123707335> in <cell line: 1>()
# ----> 1 plt.plot(df_merged.index, df_merged['SP500'])
#       2 plt.plot(df_merged.index, df_merged['RRPONTSYD'])
#
# NameError: name 'df_merged' is not defined

# %%
fig,ax = plt.subplots()
ax.plot(df_merged.index,
df_merged['DJIA'],color="blue",marker="o")
ax2=ax.twinx()
ax2.plot(df_merged.index,
df_merged['RRPONTSYD'],color="red")
fig.savefig('折線圖.jpg',format='jpeg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e9aea54f2648> in <cell line: 2>()
#       1 fig,ax = plt.subplots()
# ----> 2 ax.plot(df_merged.index,
#       3 df_merged['SP500'],color="blue",marker="o")
#       4 ax2=ax.twinx()
#       5 ax2.plot(df_merged.index,
#
# NameError: name 'df_merged' is not defined
